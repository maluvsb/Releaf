# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
sns.set(style="whitegrid")
sns.set_context("notebook")

# %%
def treatment(df):
	df=df.rename(columns={
		"Shimmer_86CF_Timestamp_Unix_CAL":"timestamp", 
        "Shimmer_86CF_GSR_Range_CAL":"range", 
        "Shimmer_86CF_GSR_Skin_Conductance_CAL":"conductance", 
        "Shimmer_86CF_GSR_Skin_Resistance_CAL":"resistance",
		})
	return df

# %%
gsr=treatment(pd.read_csv("Teste10_Session1_Shimmer_86CF_Calibrated_SD.csv",sep="	",skiprows=[0, 2])).drop("Unnamed: 4", axis=1)

# %%
gsr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28458 entries, 0 to 28457
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    28458 non-null  float64
#  1   range        28458 non-null  float64
#  2   conductance  28458 non-null  float64
#  3   resistance   28458 non-null  float64
# dtypes: float64(4)
# memory usage: 889.4 KB

# %%
gsr=gsr[gsr["timestamp"]>gsr["timestamp"].min()+60000]
gsr_basal=gsr[gsr["timestamp"]<gsr["timestamp"].min()+55000]
gsr_median = np.median(gsr_basal["conductance"])

# %%
plt.axhline(y=gsr_median, color="purple",linestyle='-')
sns.lineplot(x="timestamp",y="conductance", data=gsr_basal)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='conductance'>

# %%
gsr_estresse = gsr[gsr["timestamp"]>gsr["timestamp"].min()+55000+50000]
gsr_estresse = gsr_estresse[gsr_estresse["timestamp"]<gsr_estresse["timestamp"].min()+129000]

# %%
plt.axhline(y=gsr_median, color="purple",linestyle='-')
sns.lineplot(x="timestamp",y="conductance", data=gsr_estresse)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='conductance'>

# %%
gsr_respiracao = gsr[gsr["timestamp"]>gsr["timestamp"].min()+60000+50000+129000+125000]
gsr_respiracao = gsr_respiracao[gsr_respiracao["timestamp"]<gsr_respiracao["timestamp"].min()+158000]

# %%
plt.axhline(y=gsr_median, color="purple",linestyle='-')
sns.lineplot(x="timestamp",y="conductance", data=gsr_respiracao)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='conductance'>
